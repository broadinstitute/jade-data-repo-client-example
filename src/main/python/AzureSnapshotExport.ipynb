# %% [markdown]
# ### Azure Snapshot Export Example
#  This notebook:
#  - Exports an Azure snapshot using python client (Same call can be made from swagger/curl)
#  - Reads from parquet file included in the output from the export

# %% [markdown]
# # Setup

# %%
# %%capture
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install --upgrade data_repo_client
# !{sys.executable} -m pip install pyarrow
# !{sys.executable} -m pip install fastparquet
# !{sys.executable} -m pip install google-cloud-bigquery
# !{sys.executable} -m pip install google-cloud-storage

import pandas as pd
# import pyarrow as pa
import datetime, uuid, urllib, os, time, getpass, uuid, json
# from tdr_utils import TdrUtils
import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)
from data_repo_client import ApiClient, ApiException, Configuration, DatasetsApi, SnapshotsApi, JobsApi, ResourcesApi, DataRepositoryServiceApi
from IPython.core.display import display, clear_output, HTML
from tdr_utils import TdrUtils

# %% [markdown]
# ### Authenticate
#
# Retrieve your access token by running these commands in your terminal
#
#   1. Login in with desired user
#
# `gcloud auth login`
#
#   2. Print the token to use in the next step
#
# `gcloud auth print-access-token`

# %%
# Set up configuration
config = Configuration()
config.host="https://data.shelbee.bee.envs-terra.bio/"

# Use access token printed in last step
config.access_token= getpass.getpass("Paste token data ")
apiClient = ApiClient(configuration=config)
apiClient.client_side_validation = False

# Create required API Clients
snapshots_api = SnapshotsApi(api_client=apiClient)
jobs_api = JobsApi(api_client=apiClient)
tdr_utils = TdrUtils(jobs_api)

# %% [markdown]
# # Snapshot Export

# %%
# Example Snapshot/table to export
exisitingSnapshotId = 'e3638824-9ed9-408e-b3f5-cba7585658a3'
exampleTableName = 'variant'

# View data using TDR endpoint
snapshots_api.lookup_snapshot_preview_by_id(exisitingSnapshotId, exampleTableName)
# Out:
# {'filtered_row_count': 1004,
#  'result': [{'alt': 'C',
#              'chromosome': '1',
#              'datarepo_row_id': '004EF96A-F144-44FE-B86D-9F77296107EC',
#              'id': '1:85011183:A:C',
#              'position': 85011183,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '00728302-8D2B-40FA-986F-8197D9DC8924',
#              'id': '1:93814411:A:G',
#              'position': 93814411,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '00D535C6-4E97-452C-A0B6-7D0B9BB77EF6',
#              'id': '1:232940972:A:G',
#              'position': 232940972,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '0150F103-7093-40F7-B189-B94FB428BAA2',
#              'id': '1:195697623:A:G',
#              'position': 195697623,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '01755F37-F74B-4AE0-9835-5E67B8885B7F',
#              'id': '1:85072091:A:G',
#              'position': 85072091,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '02A5A3D7-58D9-4DCD-871B-F486604FD7E2',
#              'id': '1:119029958:A:G',
#              'position': 119029958,
#              'reference': 'A'},
#             {'alt': 'C',
#              'chromosome': '1',
#              'datarepo_row_id': '02D21B38-EA66-4013-8ADF-6F58268C6BB9',
#              'id': '1:153090512:A:C',
#              'position': 153090512,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '0363372F-41CA-4519-8E58-2EBD5B595B42',
#              'id': '1:106480412:A:G',
#              'position': 106480412,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '038171C0-EAA4-4F39-AAAC-BBBEA2C8CE02',
#              'id': '1:34891798:A:G',
#              'position': 34891798,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '038E0C4D-543E-4D76-8870-000A8DCC12BE',
#              'id': '1:49906965:A:G',
#              'position': 49906965,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '03A9EADD-2856-4FDD-BA88-4E92C0DEFDDD',
#              'id': '1:212258602:A:G',
#              'position': 212258602,
#              'reference': 'A'},
#             {'alt': 'C',
#              'chromosome': '1',
#              'datarepo_row_id': '03B71592-3673-4D72-A670-AD2197396C94',
#              'id': '1:185015184:A:C',
#              'position': 185015184,
#              'reference': 'A'},
#             {'alt': 'C',
#              'chromosome': '1',
#              'datarepo_row_id': '03C6E325-2661-46D4-95AE-CD32581B8D64',
#              'id': '1:18639371:A:C',
#              'position': 18639371,
#              'reference': 'A'},
#             {'alt': 'C',
#              'chromosome': '1',
#              'datarepo_row_id': '03D22806-2135-44A8-A756-862DE588E196',
#              'id': '1:239871505:A:C',
#              'position': 239871505,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '03D5CBF7-3F66-4A2C-865B-804296C2A3A4',
#              'id': '1:30371769:A:G',
#              'position': 30371769,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '047F4E7C-E376-45E2-A75D-F4230F6C067C',
#              'id': '1:85316724:A:G',
#              'position': 85316724,
#              'reference': 'A'},
#             {'alt': 'C',
#              'chromosome': '1',
#              'datarepo_row_id': '04A04643-CA4D-4B96-B192-91378F8C82E9',
#              'id': '1:43600679:A:C',
#              'position': 43600679,
#              'reference': 'A'},
#             {'alt': 'C',
#              'chromosome': '1',
#              'datarepo_row_id': '04DAF9D4-9EB1-4BDC-96EE-382C639613B9',
#              'id': '1:152057656:A:C',
#              'position': 152057656,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '0516D826-4BA2-47E1-8118-CDDCF2941C05',
#              'id': '1:155891436:A:G',
#              'position': 155891436,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '054B9884-4B93-4558-92D1-D98D29348CB2',
#              'id': '1:170188010:A:G',
#              'position': 170188010,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '05E6ACC7-53FA-4F90-B19A-8488F0EB3E6F',
#              'id': '1:18408705:A:G',
#              'position': 18408705,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '05F4208F-6C22-4D11-B8A9-58F2314582A6',
#              'id': '13:52895123:G:T',
#              'position': 231395857,
#              'reference': 'A'},
#             {'alt': 'C',
#              'chromosome': '1',
#              'datarepo_row_id': '06AAFFDE-E32D-4FBC-80B0-04BFA7904FDE',
#              'id': '1:145530321:A:C',
#              'position': 145530321,
#              'reference': 'A'},
#             {'alt': 'C',
#              'chromosome': '1',
#              'datarepo_row_id': '072040EF-4B9C-4BF4-871C-CF4D89C34DBB',
#              'id': '1:24417425:A:C',
#              'position': 24417425,
#              'reference': 'A'},
#             {'alt': 'C',
#              'chromosome': '1',
#              'datarepo_row_id': '07DC6A7D-8AAE-4E6F-9F85-2FBFC2237DB9',
#              'id': '1:107490554:A:C',
#              'position': 107490554,
#              'reference': 'A'},
#             {'alt': 'C',
#              'chromosome': '1',
#              'datarepo_row_id': '07F806CC-C97E-44D0-A6E6-8DAD1E008A5E',
#              'id': '1:192435352:A:C',
#              'position': 192435352,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '081E0CC9-2F2B-4ECD-83CD-21F6A50F312B',
#              'id': '1:37708193:A:G',
#              'position': 37708193,
#              'reference': 'A'},
#             {'alt': 'C',
#              'chromosome': '1',
#              'datarepo_row_id': '089F9B9B-534D-4453-90A6-D26087923FD1',
#              'id': '1:87532809:A:C',
#              'position': 87532809,
#              'reference': 'A'},
#             {'alt': 'G',
#              'chromosome': '1',
#              'datarepo_row_id': '08A98EB0-0269-4D04-A20E-85E98827D59F',
#              'id': '1:115231550:A:G',
#              'position': 115231550,
#              'reference': 'A'},
#             {'alt': 'C',
#              'chromosome': '1',
#              'datarepo_row_id': '08F1623B-4D6F-484B-9D5C-93E15AD60079',
#              'id': '1:6451004:A:C',
#              'position': 6451004,
#              'reference': 'A'}],
#  'total_row_count': 1004}

# %%
# Now, let's export the snapshot and take a look at the same "variant" table
export_snapshot_result = tdr_utils.wait_for_job(snapshots_api.export_snapshot(exisitingSnapshotId,  validate_primary_key_uniqueness='false'))
# Out:
# <b>Running job "Export snapshot V2FByFullView (e3638824-9ed9-408e-b3f5-cba7585658a3)" (kilo4AXjRNWi-D3Kph9dgA): <span style="color:rgb(116, 174, 6);">succeeded</span></b>
# <p>Job result is:</p><hr/><pre>{
#     "snapshot": {
#         "id": "e3638824-9ed9-408e-b3f5-cba7585658a3",
#         "name": "V2FByFullView",
#         "description": "snapshot by full view",
#         "createdDate": "2023-11-06T01:54:03.563472Z",
#         "consentCode": null,
#         "source": [
#             {
#                 "dataset": {
#                     "id": "bacde22b-fb48-4d64-9863-a09704015d7d",
#                     "name": "Azure_V2F_Stats",
#                     "description": "Summary statistics from V2F datasets",
#                     "defaultProfileId": "e14b3b8a-54a7-4878-969b-fc4c0478cb9c",
#                     "createdDate": "2023-10-20T18:57:30.092860Z",
#                     "storage": [
#                         {
#                             "region": "centralus",
#                             "cloudResource": "application_deployment",
#                             "cloudPlatform": "azure"
#                         },
#                         {
#                             "region": "centralus",
#                             "cloudResource": "storage_account",
#                             "cloudPlatform": "azure"
#                         },
#                         {
#                             "region": "centralus",
#                             "cloudResource": "synapse_workspace",
#                             "cloudPlatform": "azure"
#                         }
#                     ],
#                     "secureMonitoringEnabled": false,
#                     "cloudPlatform": "azure",
#                     "dataProject": null,
#                     "storageAccount": "tdrsheagjudbqsygpddezygu",
#                     "phsId": null,
#                     "selfHosted": false,
#                     "predictableFileIds": false,
#                     "tags": [],
#                     "resourceLocks": {
#                         "exclusive": null
#                     }
#                 },
#                 "datasetProperties": null,
#                 "asset": null
#             }
#         ],
#         "tables": [
#             {
#                 "name": "ancestry_specific_meta_analysis",
#                 "columns": [
#                     {
#                         "name": "variant_id",
#                         "datatype": "string",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "phenotype",
#                         "datatype": "string",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "ancestry",
#                         "datatype": "string",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "p_value",
#                         "datatype": "float",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "beta",
#                         "datatype": "float",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "std_err",
#                         "datatype": "float",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "n",
#                         "datatype": "integer",
#                         "array_of": false,
#                         "required": false
#                     }
#                 ],
#                 "primaryKey": [],
#                 "partitionMode": "none",
#                 "datePartitionOptions": null,
#                 "intPartitionOptions": null,
#                 "rowCount": 1000
#             },
#             {
#                 "name": "frequency_analysis",
#                 "columns": [
#                     {
#                         "name": "variant_id",
#                         "datatype": "string",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "eaf",
#                         "datatype": "float",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "maf",
#                         "datatype": "float",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "ancestry",
#                         "datatype": "string",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "phenotype",
#                         "datatype": "string",
#                         "array_of": false,
#                         "required": false
#                     }
#                 ],
#                 "primaryKey": [],
#                 "partitionMode": "none",
#                 "datePartitionOptions": null,
#                 "intPartitionOptions": null,
#                 "rowCount": 1003
#             },
#             {
#                 "name": "trans_ethnic_meta_analysis",
#                 "columns": [
#                     {
#                         "name": "variant_id",
#                         "datatype": "string",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "phenotype",
#                         "datatype": "string",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "p_value",
#                         "datatype": "float",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "beta",
#                         "datatype": "float",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "std_err",
#                         "datatype": "float",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "n",
#                         "datatype": "integer",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "top",
#                         "datatype": "boolean",
#                         "array_of": false,
#                         "required": false
#                     }
#                 ],
#                 "primaryKey": [],
#                 "partitionMode": "none",
#                 "datePartitionOptions": null,
#                 "intPartitionOptions": null,
#                 "rowCount": 0
#             },
#             {
#                 "name": "dataset_specific_analysis",
#                 "columns": [
#                     {
#                         "name": "variant_id",
#                         "datatype": "string",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "multi_allelic",
#                         "datatype": "boolean",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "dataset",
#                         "datatype": "string",
#                         "array_of": false,
#                         "required": false
#                     },
#                     {
#                         "name": "phenotype",
#                         "datatype": "string",

# %% [markdown]
# # Copy Azure Parquet Files to GCP Bucket
# Towards the bottom of the export, we can find the signed URLs for the JSON manifest and the parquet files containing the tabular data.

# %%
variantParquet = export_snapshot_result['format']['parquet']['location']['tables'][0]['paths'][1]
print(variantParquet)
# Out:
# https://tdrsheagjudbqsygpddezygu.blob.core.windows.net/e3638824-9ed9-408e-b3f5-cba7585658a3/metadata%2Fparquet%2Fancestry_specific_meta_analysis%2Fancestry_specific_meta_analysis.parquet%2F2E96FCE6-DD21-4BAC-AF59-E7EE29168B4D_2477_0-1.parquet?sv=2022-11-02&spr=https&se=2023-11-06T02%3A24%3A51Z&sp=rl&sig=c2wbR%2B6%2FYnVEzNZBi8qlOXoz%2BdJHkTZWdEMrz3fXxaY%3D&sr=c&rscd=sholdendev%40gmail.com

# %%
destinationBucket = "test-data-sholden/test-parquet-export"
# Copy parquet file for variant table to GCS
destinationFileName = "testFile.parquet"
# !{sys.executable} -m wget -O - testSourceUrl  | gcloud storage cp - "gs://{destinationBucket}/{destinationFileName}"
# Out:
# /usr/local/opt/python@3.9/bin/python3.9: No module named wget
# WARNING: Using sequential instead of parallel task execution to transfer from stdin.
# Copying file://- to gs://test-data-sholden/test-parquet-export/testFile.parquet
#
# .

# %% [markdown]
# # Import parquet to BigQuery

# %%
from google.cloud import bigquery

existing_gcp_project = "broad-jade-sh"
existing_dataset_name = "test_parquet_export"
new_table_name = "variantTable"

# Construct a BigQuery client object.
client = bigquery.Client(project=existing_gcp_project)
# Set table_id to the ID of the table to create.
table_id = "{}.{}.{}".format(existing_gcp_project, existing_dataset_name, new_table_name)

job_config = bigquery.LoadJobConfig(
    source_format=bigquery.SourceFormat.PARQUET,
)
#uri = "gs://{}/{}".format(destinationBucket, destinationFileName)
## MANUAL OVERRIDE BECAUSE COPIED FILE ISN'T WORKING
uri = "gs://test-data-sholden/test-parquet-export/41F221D2-4864-4CA7-9C69-787EF7C4D38C_2480_0-1.parquet"

load_job = client.load_table_from_uri(
    uri, table_id, job_config=job_config
)  # Make an API request.

load_job.result()  # Waits for the job to complete.

destination_table = client.get_table(table_id)
print("Loaded {} rows.".format(destination_table.num_rows))
# Out:
# Loaded 1004 rows.
